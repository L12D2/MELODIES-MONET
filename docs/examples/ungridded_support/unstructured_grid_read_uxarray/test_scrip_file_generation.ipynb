# %%
#!pip install uxarray

import uxarray as ux
import xarray as xr
import os
import subprocess
from pathlib import Path

# %%
cesm_se_file = "/glade/campaign/acom/acom-da/conus_outputs/f.e22.FCnudged.ne0CONUSne30x8_ne0CONUSne30x8_mt12.ERA5_ref_dust_M1.1.002/H1/f.e22.FCnudged.ne0CONUSne30x8_ne0CONUSne30x8_mt12.ERA5_ref_dust_M1.1.002.cam.h1.2024-01-01-03600.nc"
grid_file = "/glade/campaign/acom/acom-da/conus_outputs/grid/ne0CONUS_ne30x8_EXODUS.nc"
output_dir = '/glade/u/home/lcthompson/mm/MELODIES-MONET/docs/examples/ungridded_support/unstructured_grid_read_uxarray/output'

uxds = ux.open_dataset(grid_file, cesm_se_file)
print(uxds.uxgrid)

ds = uxds  
print("\nDataset variables:")
print(list(ds.data_vars))
# Out:
# <uxarray.Grid>
# Original Grid Type: Exodus
# Grid Dimensions:
#   * n_node: 19346
#   * n_face: 19344
#   * n_max_face_nodes: 4
# Grid Coordinates (Spherical):
#   * node_lon: (19346,)
#   * node_lat: (19346,)
# Grid Coordinates (Cartesian):
#   * node_x: (19346,)
#   * node_y: (19346,)
#   * node_z: (19346,)
# Grid Connectivity Variables:
#   * face_node_connectivity: (19344, 4)
# Grid Descriptor Variables:
#
#
# Dataset variables:
# ...
